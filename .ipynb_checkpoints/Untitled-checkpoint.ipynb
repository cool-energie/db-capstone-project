# %%
import mysql.connector as connector

# %%
# task 1
connection = connector.connect(user = "root", password = "")

# %%
# task 2
cursor = connection.cursor()
cursor.execute("USE littlelemondb")

show_tables_query = "SHOW tables" 
cursor.execute(show_tables_query)

results = cursor.fetchall()
print(results)
# Out:
# [('address',), ('bookings',), ('customers',), ('employees',), ('menuitems',), ('menus',), ('orders',), ('shippings',)]

# %%
# task 3
select = """
SELECT CONCAT(c.FirstName, ' ', c.LastName) AS FullName, c.ContactNumber
FROM customers c
INNER JOIN orders o ON o.CustomerID = c.CustomerID
WHERE o.TotalCost > 60
"""

cursor.execute(select)
results = cursor.fetchall()
for r in results:
    print(r)
# Out:
# ('Marc Tchoua', '+237655443322')
# ('Laura Nkem', '+237699887766')
# ('Pierre Durand', '+33123456789')
# ('Sarah Ngono', '+237677112233')
# ('David Smith', '+12125551234')
